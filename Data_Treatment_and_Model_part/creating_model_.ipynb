# %%
import os
import csv
import pandas as pd
import numpy as np
import math
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# No collision df

# %%
# %cd drive/MyDrive/Rafel-Satellitecollision-GSoC2023/data/no_collision/tle_sat
# Out:
# /content/drive/.shortcut-targets-by-id/1NyJDOWUmDY1vQY1mod9dhwk8XC_AaT3-/Rafel-Satellitecollision-GSoC2023/data/no_collision/tle_sat

# %%
all_non_colision_satellites = pd.read_csv('all_data_sat_no_colision.csv')

# %%
# %cd ..
# Out:
# /content/drive/.shortcut-targets-by-id/1NyJDOWUmDY1vQY1mod9dhwk8XC_AaT3-/Rafel-Satellitecollision-GSoC2023/data/no_collision

# %%
# %cd ..
# Out:
# /content/drive/.shortcut-targets-by-id/1NyJDOWUmDY1vQY1mod9dhwk8XC_AaT3-/Rafel-Satellitecollision-GSoC2023/data

# %%
# %cd collision
# Out:
# [Errno 2] No such file or directory: 'collision'
# /content/drive/.shortcut-targets-by-id/1NyJDOWUmDY1vQY1mod9dhwk8XC_AaT3-/Rafel-Satellitecollision-GSoC2023/data/collision

# %%
all_collided_satellites = pd.read_csv('collision_satellites.csv')

# %%
all_sats_df = pd.concat([all_collided_satellites, all_non_colision_satellites])

# %%
all_sats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12032 entries, 0 to 11763
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                12032 non-null  int64
#  1   satellite_name            268 non-null    object
#  2   international_designator  268 non-null    object
#  3   us_satellite_number       268 non-null    float64
#  4   launch_date               268 non-null    object
#  5   breakup_date              268 non-null    object
#  6   debris_cataloged          268 non-null    float64
#  7   debris_left               268 non-null    float64
#  8   apogee                    268 non-null    float64
#  9   perigee                   268 non-null    float64
#  10  inclination               268 non-null    object
#  11  assessed_cause            268 non-null    object
#  12  additional_information    233 non-null    object
#  13  location                  267 non-null    object
#  14  date                      267 non-null    object
#  15  time                      267 non-null    object
#  16  OBJECT_NAME               11764 non-null  object
#  17  OBJECT_ID                 11764 non-null  object
#  18  EPOCH                     11764 non-null  object
#  19  MEAN_MOTION               11764 non-null  float64
#  20  ECCENTRICITY              11764 non-null  float64
#  21  INCLINATION               11764 non-null  float64
#  22  RA_OF_ASC_NODE            11764 non-null  float64
#  23  ARG_OF_PERICENTER         11764 non-null  float64
#  24  MEAN_ANOMALY              11764 non-null  float64
#  25  EPHEMERIS_TYPE            11764 non-null  float64
#  26  CLASSIFICATION_TYPE       11764 non-null  object
#  27  NORAD_CAT_ID              11764 non-null  float64
#  28  ELEMENT_SET_NO            11764 non-null  float64
#  29  REV_AT_EPOCH              11764 non-null  float64
#  30  BSTAR                     11764 non-null  float64
#  31  MEAN_MOTION_DOT           11764 non-null  float64
#  32  MEAN_MOTION_DDOT          11764 non-null  float64
#  33  POSITION 0                11764 non-null  object
#  34  POSITION 1                11764 non-null  object
#  35  POSITION 2                11764 non-null  object
#  36  POSITION 3                11764 non-null  object
#  37  POSITION 4                11764 non-null  object
#  38  POSITION 5                11764 non-null  object
#  39  POSITION 6                11764 non-null  object
#  40  POSITION 7                11764 non-null  object
#  41  POSITION 8                11764 non-null  object
#  42  POSITION 9                11764 non-null  object
#  43  POSITION 10               11764 non-null  object
#  44  POSITION 11               11764 non-null  object
#  45  tle_line1                 11764 non-null  object
#  46  tle_line2                 11764 non-null  object
# dtypes: float64(18), int64(1), object(28)
# memory usage: 4.4+ MB
